# %% [markdown]
# ## Web Scraping to build a Football News Aggregator

# %% [markdown]
# ### 1. Import the necessary libraries
# ### 2. Provide the url to the home page for Spanish soccer news
# ### 3. Hit the url and fetch the response
# ### 4. Extract the HTML and identify the tags to La Liga news articles’ links
# ### 5. Collect all the links through BeautifulSoup
# ### 6. Crawl each of the collected links
# ### 7. Extract title and published date through BeautifulSoup after inspecting HTML tags
# ### 8. As long as the designs for these websites don’t change, our news aggregator will work just fine

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

df = pd.DataFrame(columns=('title', 'date', 'link'))

############################################Givemesport.com#######################################################################
gms_url = "http://www.givemesport.com/spain-football"
gms_response = requests.get(gms_url)
gms_html = gms_response.text
gms_soup = BeautifulSoup(gms_html, "lxml")
headlines = []
for headline_tag in  gms_soup.find_all('h2', class_='gms-feature-title'):
    news_link = str('http://www.givemesport.com/')+headline_tag.find_all('a', href=True)[0]['href']
    if news_link not in headlines:
        try:
            headlines.append(news_link)
        except:
            pass
#print headlines

i = 0
for headline in headlines:
    response = requests.get(headline)
    html = response.text 
    soup = BeautifulSoup(html, "lxml")
    details = {'title' : soup.title.text, 
            'date' : soup.find_all('p', class_='gms-article-data')[0].find_all('time', datetime=True)[0]['datetime'][0:10],
            'link' : headline} 
    #print details
    df.loc[i] = [details['title'], 
                 details['date'], 
                 details['link']]

    i += 1
############################################Goal.com############################################################################   

goal_url = "http://www.goal.com/en-us/news/88/spain/archive/1?ICID=SP_TN_7_4_1"
goal_response = requests.get(goal_url)
goal_html = goal_response.text
goal_soup = BeautifulSoup(goal_html, "lxml")
headlines = []
for headline_tag in  goal_soup.find_all('h4', class_='headline'):
    news_link = str('http://www.goal.com')+headline_tag.find_all('a', href=True)[0]['href']
    if news_link not in headlines:
        try:
            headlines.append(news_link)
        except:
            pass
#print headlines

try:
    for headline in headlines:
        response = requests.get(headline)
        html = response.text 
        soup = BeautifulSoup(html, "lxml")
        details = {'title' : soup.title.text, 
                'date' : soup.find_all('div', class_='module module-article-body clearfix')[0]\
                   .find_all('time', datetime=True)[0]['datetime'][0:10],
                'link' : str(headline)} 
        #print details
        df.loc[i] = [details['title'], 
                     details['date'], 
                     details['link']]
        i += 1
except:
    pass

############################################Sportskeeda.com############################################################################
sportskeeda_url = "http://www.sportskeeda.com/go/la-liga"
sportskeeda_response = requests.get(sportskeeda_url)
sportskeeda_html = sportskeeda_response.text
sportskeeda_soup = BeautifulSoup(sportskeeda_html, "lxml")
headlines = []
for headline_tag in  sportskeeda_soup.find_all('div', class_='story-wrapper'):
    news_link = str('http://www.sportskeeda.com')+headline_tag.find_all('a', href=True)[0]['href']
    if news_link not in headlines:
        try:
            headlines.append(news_link)
        except:
            pass

for headline in headlines:
    response = requests.get(headline)
    html = response.text 
    soup = BeautifulSoup(html, "lxml")
    details = {'title' : soup.title.text, 
            'date' : str(soup.find("meta", {"property":"article:published_time"}, content=True))[15:25],
            'link' : str(headline)} 
    #print details
    if soup.find("meta", {"property":"article:published_time"}, content=True) is not None:
        df.loc[i] = [details['title'] + ' | Sportskeeda.com', 
                     details['date'], 
                     details['link']]
    else:
        continue
    i += 1
    
#print df.sort_values(by='date', ascending=False).reset_index().drop('index', axis=1)

# %%
# Clasico hangover? Madrid make it club record 3...  2016-12-07  http://www.goal.com/en-us/news/88/spain/2016/1...
# Arda atones for Madrid mistake, but Alcacer's ...  2016-12-06  http://www.goal.com/en-us/news/88/spain/2016/1...
# Ramos the hero again as Neymar & Messi miss ch...  2016-12-03  http://www.goal.com/en-us/news/88/spain/2016/1...
# Real winner: would another Clasico success con...  2016-12-02  http://www.goal.com/en-us/news/88/spain/2016/1...
# From extraordinary to ordinary: What happened ...  2016-12-01  http://www.goal.com/en-us/news/88/spain/2016/1...
# Messi, Neymar and little else - Barcelona midf...  2016-11-27  http://www.goal.com/en-us/news/88/spain/2016/1...
# Ronaldo rounds off perfect week as Madrid pile...  2016-11-26  http://www.goal.com/en-us/news/88/spain/2016/1...

# %%
sortedDF = df.sort_values(by='date', ascending=False).reset_index().drop('index', axis=1)

# %%
#print sortedDF

# %%
length = len(sortedDF)
for i in range(0,length):
    with open("NewsAggregator.txt", "a") as myfile:
        myfile.write('##Article ' + str(i+1) + '##' + '\n')
        myfile.write(sortedDF['title'][i].encode('utf8')+'\n')
        myfile.write(sortedDF['date'][i].encode('utf8')+'\n')
        myfile.write(sortedDF['link'][i].encode('utf8')+'\n'+'\n')

# %%
length = len(sortedDF)
for i in range(0,length):
    print('##Article ' + str(i+1) + '##')
    print(sortedDF['title'][i].encode('utf8'))
    print(sortedDF['date'][i].encode('utf8'))
    print(sortedDF['link'][i].encode('utf8')+'\n')
# Out:
# ##Article 1##
# Transfer news and rumours of the day: 16th January, 2017 | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/transfer-news-and-rumours-of-the-day-16th-january-2017/
#
# ##Article 2##
# Real Madrid transfer rumour: Los Blancos plot Isco-Dele Alli swap deal | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/real-madrid-transfer-rumour-los-blancos-isco-dele-alli/
#
# ##Article 3##
# Pogba: I rejected Barcelona and Real Madrid for Man Utd - Goal.com
# 2017-01-16
# http://www.goal.com/en-us/news/88/spain/2017/01/16/31601452/pogba-i-rejected-barcelona-and-real-madrid
#
# ##Article 4##
# Messi and Barcelona need each other - Mascherano - Goal.com
# 2017-01-16
# http://www.goal.com/en-us/news/88/spain/2017/01/16/31590172/messi-and-barcelona-need-each-other-mascherano
#
# ##Article 5##
# Top 5 players who have scored against most clubs in La Liga | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/top-5-players-who-have-scored-against-most-clubs-la-liga/
#
# ##Article 6##
# 10 greatest Barcelona players of all time | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/lionel-messi-andres-iniesta-10-greatest-barcelona-players/
#
# ##Article 7##
# 10 most expensive players in the transfer market today - as determined by statisticians  | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/10-most-expensive-players-transfer-market-2017/
#
# ##Article 8##
# 10 great players who were relegated  | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/10-great-players-relegated/
#
# ##Article 9##
# 4 facts you need to know about Real Madrid and Spain's Sergio Ramos | Sportskeeda.com
# 2017-01-16
# http://www.sportskeeda.com/football/4-facts-you-need-know-real-madrid-spain-sergio-ramos/
#
# ##Article 25##
# Transfer Rumour: Real Madrid close to completing signing of 'next Zlatan Ibrahimovic', Alexander Isak | Sportskeeda.com
# 2017-01-15
# http://www.sportskeeda.com/football/real-madrid-close-to-completing-transfer-of-next-zlatan-ibrahimovic-alexander-isak/
#
# ##Article 26##
# Paco Alcacer, Arda Turan, Andre Gomes, Aleix Vidal - Barcelona's second string step up to help Lionel Messi & Luis Suarez - Goal.com
# 2017-01-14
# http://www.goal.com/en-us/news/88/spain/2017/01/14/31529162/alcacer-arda-gomes-vidal-barcelonas-second-string-step-up-to
#
# ##Article 27##
# Diego Costa sends Instagram post after Antonio Conte row emerges | GiveMeSport
# 2017-01-13
# http://www.givemesport.com//961937-diego-costa-sends-instagram-post-after-antonio-conte-row-emerges
#
# ##Article 28##
# Diego Costa had blazing row with Antonio Conte that throws Chelsea future into doubt | GiveMeSport
# 2017-01-13
# http://www.givemesport.com//961752-diego-costa-had-blazing-row-with-antonio-conte-that-throws-chelsea-future-into-doubt
#
# ##Article 29##
# Antonio Conte shouted three words at Diego Costa after training ground argument | GiveMeSport
# 2017-01-13
# http://www.givemesport.com//961823-antonio-conte-shouted-three-words-at-diego-costa-after-training-ground-argument
#
# ##Article 30##
# Messi business: Barca need to get priorities right after latest PR disaster - Goal.com
# 2017-01-13
# http://www.goal.com/en-us/news/88/spain/2017/01/13/31495812/messi-business-barca-need-to-get-priorities-right-after
#
# ##Article 31##
# Does Martin Odegaard have a future at Real Madrid? - Goal.com
# 2017-01-13
# http://www.goal.com/en-us/news/88/spain/2017/01/13/31482292/does-martin-odegaard-have-a-future-at-real-madrid
#
# ##Article 32##
# Marco Asensio scores wonderful solo goal for Real Madrid against Sevilla | GiveMeSport
# 2017-01-12
# http://www.givemesport.com//961103-marco-asensio-scores-wonderful-solo-goal-for-real-madrid-against-sevilla
#
# ##Article 33##
# Just like old times in landmark match for Messi, Suarez & Neymar - Goal.com
# 2017-01-11
# http://www.goal.com/en-us/news/88/spain/2017/01/11/31418642/just-like-old-times-in-landmark-match-for-messi-suarez
#
# ##Article 34##
# Gerard Pique reacted angrily to referee denying second penalty vs Villarreal | GiveMeSport
# 2017-01-11
# http://www.givemesport.com//959798-gerard-pique-reacted-angrily-to-referee-denying-second-penalty-vs-villarreal
#
# ##Article 35##
# Andres Iniesta called Real Madrid players after The Best FIFA awards | GiveMeSport
# 2017-01-10
# http://www.givemesport.com//959107-andres-iniesta-called-real-madrid-players-after-the-best-fifa-awards
#
# ##Article 36##
# Simply The Best! Ronaldo completes clean sweep after greatest-ever year - Goal.com
# 2017-01-09
# http://www.goal.com/en-us/news/88/spain/2017/01/09/31321682/simply-the-best-ronaldo-completes-clean-sweep-after-greatest
#
# ##Article 37##
# Snubbing FIFA and referee rants - are Barcelona morphing into Mourinho's Madrid? - Goal.com
# 2017-01-09
# http://www.goal.com/en-us/news/88/spain/2017/01/09/31321972/snubbing-fifa-and-referee-rants-are-barcelona-morphing-into
#
# ##Article 38##
# Gerard Pique appears to call out La Liga president Javier Tebas after Villarreal 1-1 Barcelona | GiveMeSport
# 2017-01-08
